# %%
import torch

x = torch.rand(3,4)
print(x)
print(x.shape)
# Out:
# tensor([[0.6021, 0.2544, 0.4446, 0.1696],
#         [0.6548, 0.5371, 0.3580, 0.2993],
#         [0.7654, 0.3232, 0.4873, 0.6244]])
# torch.Size([3, 4])
